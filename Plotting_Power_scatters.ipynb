# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Merged_df = pd.read_csv('./Datasets/Production_data/Merged_Superhero.csv')
Merged_df.head()
# Out:
#    Unnamed: 0  Date_Released Publisher Superhero_Name  \
# 0           0           2008        DC         Batman
# 1           1           2008        DC       Punisher
# 2           2           2008    Marvel       Iron Man
# 3           3           2008    Marvel           Hulk
# 4           4           2009    Marvel      Wolverine
#
#                 Movie_Title  Rating IMDB_Votes  Box_Office_Sales Gender  \
# 0           The Dark Knight    90.0  2,029,721         533316061   Male
# 1        Punisher: War Zone    60.0     56,730           7948159   Male
# 2                  Iron Man    79.0    842,429         318298180   Male
# 3       The Incredible Hulk    68.0    388,957         134518390   Male
# 4  X-Men Origins: Wolverine    66.0    431,892         179737340   Male
#
#   Eye color               Race Hair color  Height Skin color Alignment  \
# 0      blue              Human      black     188          -      good
# ...

# %%
plt.scatter(Merged_df['Weight'],Merged_df['Inflation_Sales'], s=50, edgecolors='black', c='r', alpha=.5)
plt.xlabel('Power level of Superhero')
plt.ylabel('Inflation Adjusted Sales (Hundred of Millions)')
plt.title('Power level vs. US Sales')
plt.savefig("./Images/Scatter_Power_Sales")
plt.show()

# %%
plt.scatter(Merged_df['Weight'],Merged_df['Rating'], s=50, edgecolors='black', c='b' )
plt.xlabel('Power level of Superhero')
plt.ylabel('Movie Rating')
plt.title('Power level vs. Rating')
plt.savefig("./Images/Scatter_Rating_Sales")
plt.show()

# %%
merge_sort_power = Merged_df.sort_values(by=['Weight'], ascending=False)

# %%
plt.figure(figsize = (30,10))

# Set x axis and tick locations
x_axis = np.arange(len(merge_sort_power))
plt.xticks(x_axis, merge_sort_power.Movie_Title, rotation = 90, fontsize= 20)
plt.bar(x_axis, merge_sort_power['Weight'], color='purple', alpha=.5, align="center")
plt.yticks(fontsize = 20)

#Labels and Title
#plt.xlabel("Movie Title", fontsize= 30)
plt.ylabel("Power Level of Superhero", fontsize= 30)
plt.title("Movie vs Power Level of Superhero", fontsize= 30)

plt.tight_layout()
plt.savefig("./Images/Bar_Movie_Power")
plt.show()

# %%
merge_sort_sales = Merged_df.sort_values(by=['Inflation_Sales'], ascending=False)

# %%
plt.figure(figsize = (30,10))

# Set x axis and tick locations
x_axis = np.arange(len(merge_sort_sales))
plt.xticks(x_axis, merge_sort_sales.Movie_Title, rotation = 90, fontsize= 20)
plt.bar(merge_sort_sales['Movie_Title'], merge_sort_sales['Inflation_Sales'], color='r', alpha=.5, align="center")
plt.yticks(fontsize = 20)

#Labels and Title
#plt.xlabel("Movie Title", fontsize= 30)
plt.ylabel("Sales (Hundred Millions)", fontsize= 30)
plt.title("US Sales of Superhero Movies", fontsize= 30)

plt.tight_layout()
plt.savefig("./Images/Bar_Movie_Sales")
plt.show()

# %%
merge_sort_rating = Merged_df.sort_values(by=['Rating'], ascending=False)

# %%
plt.figure(figsize = (30,10))

# Set x axis and tick locations
x_axis = np.arange(len(merge_sort_rating))
plt.xticks(x_axis, merge_sort_rating.Movie_Title, rotation = 90, fontsize = 20)
plt.bar(merge_sort_rating['Movie_Title'], merge_sort_rating['Rating'], color='b', alpha=.5, align="center")
plt.yticks(fontsize = 20)

#Labels and Title
#plt.xlabel("Movie Title", fontsize = 30)
plt.ylabel("Movie Rating", fontsize = 30)
plt.title("Ratings (Rotten Tomatoes) of Superhero Movies", fontsize = 30)

plt.tight_layout()
plt.savefig("./Images/Bar_Movie_Rating")
plt.show()

# %%
Merged_df.head()
# Out:
#    Unnamed: 0  Date_Released Publisher Superhero_Name  \
# 0           0           2008        DC         Batman
# 1           1           2008        DC       Punisher
# 2           2           2008    Marvel       Iron Man
# 3           3           2008    Marvel           Hulk
# 4           4           2009    Marvel      Wolverine
#
#                 Movie_Title  Rating IMDB_Votes  Box_Office_Sales Gender  \
# 0           The Dark Knight    90.0  2,029,721         533316061   Male
# 1        Punisher: War Zone    60.0     56,730           7948159   Male
# 2                  Iron Man    79.0    842,429         318298180   Male
# 3       The Incredible Hulk    68.0    388,957         134518390   Male
# 4  X-Men Origins: Wolverine    66.0    431,892         179737340   Male
#
#   Eye color               Race Hair color  Height Skin color Alignment  \
# 0      blue              Human      black     188          -      good
# ...

# %%
superhero_group_df = Merged_df.groupby(['Superhero_Name'])
Sales_avg = superhero_group_df['Inflation_Sales'].mean()
Rating_avg = superhero_group_df['Rating'].mean()
Superhero_df = pd.DataFrame({'Average Sales': Sales_avg, 'Average Rating': Rating_avg})
Superhero_df.head()
# Out:
#                  Average Sales  Average Rating
# Superhero_Name
# Ant-Man           1.826378e+08            72.0
# Aquaman           3.374072e+08            72.0
# Batman            5.597524e+08            87.0
# Black Panther     5.046128e+08            73.0
# Captain America   2.213616e+08            73.5

# %%
Superhero_sales_sort_df = Superhero_df.sort_values(by=['Average Sales'], ascending=False)

# %%
plt.figure(figsize = (30,10))

# Set x axis and tick locations
x_axis = np.arange(len(Superhero_sales_sort_df))
plt.xticks(x_axis, Superhero_sales_sort_df.index, rotation = 45, fontsize = 20)
plt.bar(x_axis, Superhero_sales_sort_df['Average Sales'], color='r', alpha=.5, align="center")
plt.yticks(fontsize = 30)

#Labels and Title
#plt.xlabel("Superhero", fontsize = 30)
plt.ylabel("Sales (Hundred of Millions)", fontsize = 30)
plt.title("Average US Sales for each Superhero", fontsize = 30)

plt.tight_layout()
plt.savefig("./Images/Bar_Superhero_Sales")
plt.show()

# %%
Superhero_rating_sort_df = Superhero_df.sort_values(by=['Average Rating'], ascending=False)

# %%
plt.figure(figsize = (30,10))

# Set x axis and tick locations
x_axis = np.arange(len(Superhero_rating_sort_df))
plt.xticks(x_axis, Superhero_rating_sort_df.index, rotation = 45, fontsize = 20)
plt.bar(x_axis, Superhero_rating_sort_df['Average Rating'], color='b', alpha=.5, align="center")
plt.yticks(fontsize = 30)

#Labels and Title
#plt.xlabel("Superhero", fontsize = 30)
plt.ylabel("Average Rating", fontsize = 30)
plt.title("Average Rating for each Superhero", fontsize = 30)

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.savefig("./Images/Bar_Superhero_Rating")
plt.show()
