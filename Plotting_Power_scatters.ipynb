# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Merged_df = pd.read_csv('./Datasets/Production_data/Merged_Superhero.csv')
Merged_df.head()
# Out:
#    Unnamed: 0  Date_Released Publisher Superhero_Name  \
# 0           0           2008        DC         Batman
# 1           1           2008        DC       Punisher
# 2           2           2008    Marvel       Iron Man
# 3           3           2008    Marvel           Hulk
# 4           4           2009    Marvel      Wolverine
#
#                 Movie_Title  Rating IMDB_Votes  Box_Office_Sales Gender  \
# 0           The Dark Knight    90.0  2,029,721         533316061   Male
# 1        Punisher: War Zone    60.0     56,730           7948159   Male
# 2                  Iron Man    79.0    842,429         318298180   Male
# 3       The Incredible Hulk    68.0    388,957         134518390   Male
# 4  X-Men Origins: Wolverine    66.0    431,892         179737340   Male
#
#   Eye color               Race Hair color  Height Skin color Alignment  \
# 0      blue              Human      black     188          -      good
# ...

# %%
plt.scatter(Merged_df['Weight'],Merged_df['Inflation_Sales'])
plt.xlabel('Power level of Superhero')
plt.ylabel('Inflation Adjusted Sales')
plt.title('Power level vs. Sales')
plt.show()

# %%
plt.scatter(Merged_df['Weight'],Merged_df['Rating'])
plt.xlabel('Power level of Superhero')
plt.ylabel('Movie Rating')
plt.title('Power level vs. Rating')
plt.show()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Merged_df))
plt.xticks(x_axis, Merged_df.Movie_Title, rotation = 45)
plt.bar(x_axis, Merged_df['Weight'], color='b', alpha=.5, align="center")

# Set x and y limits
#plt.xlim(-1, len(df['State'])+1)
#plt.ylim(0, max(df['Inches'])+5)

#Labels and Title
plt.xlabel("Movie Title")
plt.ylabel("Power Level of Superhero")
plt.title("Movie vs Power Level of Superhero")

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.show()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Merged_df))
plt.xticks(x_axis, Merged_df.Movie_Title, rotation = 45)
plt.bar(Merged_df['Movie_Title'], Merged_df['Inflation_Sales'], color='b', alpha=.5, align="center")

# Set x and y limits
#plt.xlim(-1, len(df['State'])+1)
#plt.ylim(0, max(df['Inches'])+5)

#Labels and Title
plt.xlabel("Movie Title")
plt.ylabel("Sales Adjusted for Revenue (Hundred Millions)")
plt.title("Revenue of Marvel and DC Movies")

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.show()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Merged_df))
plt.xticks(x_axis, Merged_df.Movie_Title, rotation = 45)
plt.bar(Merged_df['Movie_Title'], Merged_df['Rating'], color='b', alpha=.5, align="center")

# Set x and y limits
#plt.xlim(-1, len(df['State'])+1)
#plt.ylim(0, max(df['Inches'])+5)

#Labels and Title
plt.xlabel("Movie Title")
plt.ylabel("Movie Rating")
plt.title("Ratings of Marvel and DC Movies")

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.show()

# %%
Merged_df.head()
# Out:
#    Unnamed: 0  Date_Released Publisher Superhero_Name  \
# 0           0           2008        DC         Batman
# 1           1           2008        DC       Punisher
# 2           2           2008    Marvel       Iron Man
# 3           3           2008    Marvel           Hulk
# 4           4           2009    Marvel      Wolverine
#
#                 Movie_Title  Rating IMDB_Votes  Box_Office_Sales Gender  \
# 0           The Dark Knight    90.0  2,029,721         533316061   Male
# 1        Punisher: War Zone    60.0     56,730           7948159   Male
# 2                  Iron Man    79.0    842,429         318298180   Male
# 3       The Incredible Hulk    68.0    388,957         134518390   Male
# 4  X-Men Origins: Wolverine    66.0    431,892         179737340   Male
#
#   Eye color               Race Hair color  Height Skin color Alignment  \
# 0      blue              Human      black     188          -      good
# ...

# %%
superhero_group_df = Merged_df.groupby(['Superhero_Name'])
Sales_avg = superhero_group_df['Inflation_Sales'].mean()
Rating_avg = superhero_group_df['Rating'].mean()
Superhero_df = pd.DataFrame({'Average Sales': Sales_avg, 'Average Rating': Rating_avg})
Superhero_df.head()
# Out:
#                  Average Sales  Average Rating
# Superhero_Name
# Ant-Man           1.826378e+08            72.0
# Aquaman           3.374072e+08            72.0
# Batman            5.597524e+08            87.0
# Black Panther     5.046128e+08            73.0
# Captain America   2.213616e+08            73.5

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Superhero_df))
plt.xticks(x_axis, Superhero_df.index, rotation = 45)
plt.bar(x_axis, Superhero_df['Average Sales'], color='b', alpha=.5, align="center")

# Set x and y limits
#plt.xlim(-1, len(df['State'])+1)
#plt.ylim(0, max(df['Inches'])+5)

#Labels and Title
plt.xlabel("Superhero")
plt.ylabel("Average Sales")
plt.title("Average Sales for each Superhero")

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.show()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Superhero_df))
plt.xticks(x_axis, Superhero_df.index, rotation = 45)
plt.bar(x_axis, Superhero_df['Average Rating'], color='b', alpha=.5, align="center")

# Set x and y limits
#plt.xlim(-1, len(df['State'])+1)
#plt.ylim(0, max(df['Inches'])+5)

#Labels and Title
plt.xlabel("Superhero")
plt.ylabel("Average Rating")
plt.title("Average Rating for each Superhero")

plt.tight_layout()
plt.figure(figsize = (30,10))
plt.show()
