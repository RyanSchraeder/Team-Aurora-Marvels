# %%
# import dependencies
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# movie data query from omdbapi.com

query_url = "http://www.omdbapi.com/?apikey=cf77db42&t="
print(query_url)
# Out:
# http://www.omdbapi.com/?apikey=cf77db42&t=

# %%
# selected movies
movies = ['Ant-Man',
          'Ant-Man and the Wasp',
          'Aquaman',
          'The Dark Knight',
          'The Dark Knight Rises',
          'Black Panther',
          'Captain America: The First Avenger',
          'Captain America: The Winter Soldier',
          'Captain Marvel',
          'Deadpool',
          'Deadpool 2',
          'Doctor Strange',
          'Spirit of Vengeance',
          'Green Lantern',
          'Iron Man',
          'Iron Man 2',
          'Iron Man 3',
          'Punisher: War Zone',
          'Spider-Man: Homecoming',
          'The Amazing Spider-Man',
          'The Amazing Spider-Man 2',
          'Man of Steel',
          'The Incredible Hulk',
          'Thor',
          'Thor: Ragnarok',
          'Thor: The Dark World',
          'Venom',
          'Logan',
          'The Wolverine',
          'X-Men Origins: Wolverine',
          'Wonder Woman',
]

# variables
year = []
title = []
ratings = []
imdbVotes = []
response = []


movie_data_accumulated = []

# loop through database
for movie in movies:
             
    response = requests.get(query_url + movie).json()
    year = response['Year']
    title = response['Title']
    ratings = response['Ratings'][1]['Value']
    imdbVotes = response['imdbVotes']
   
    
    #print(year, title, ratings)
    movie_data = [year, title, ratings, imdbVotes]
    #print(movie_data)
    movie_data_accumulated.append(movie_data)

# create dataframe

movie_data_df = pd.DataFrame(movie_data_accumulated, columns=('Released Year', 'Movie Title',
                                      'Rotten Tomatoes Rating', 'IMDB Votes'))
movie_data_df

### Venom does not have a rotten tomatoes rating - how can we fix this?
# Out:
#    Released Year                          Movie Title Rotten Tomatoes Rating  \
# 0           2015                              Ant-Man                    82%
# 1           2018                 Ant-Man and the Wasp                    88%
# 2           2018                              Aquaman                    65%
# 3           2008                      The Dark Knight                    94%
# 4           2012                The Dark Knight Rises                    87%
# 5           2018                        Black Panther                    97%
# 6           2011   Captain America: The First Avenger                    80%
# 7           2014  Captain America: The Winter Soldier                    90%
# 8           2019                       Captain Marvel                    79%
# 9           2016                             Deadpool                    84%
# 10          2018                           Deadpool 2                    83%
# ...

# %%
# save file
movie_data_df.to_csv('./movie_ratings.csv')
