# %%
import pandas as pd

hero_attribute = './Datasets/Production_data/Superhero_Attributes.csv'
movie_data = './Datasets/Production_data/Movie_Stats.csv'
movie_superhero_list = './Datasets/Production_data/Movie_List.csv'

attribute_df = pd.read_csv(hero_attribute)
movie_rating_sales_df = pd.read_csv(movie_data)
movie_superhero_df = pd.read_csv(movie_superhero_list)

# %%
movie_superhero_df.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title
# 0           2008        DC         Batman           The Dark Knight
# 1           2008        DC       Punisher        Punisher: War Zone
# 2           2008    Marvel       Iron Man                  Iron Man
# 3           2008    Marvel           Hulk       The Incredible Hulk
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine

# %%
movie_rating_sales_df.rename(columns={'Internet_Movie_Database_Rating':'Rating'},inplace=True)
movie_rating_sales_df.head()
# Out:
#    Unnamed: 0  Date_Released  Rating IMDB_Votes Box_Office_Sales  \
# 0           0           2008  9.0/10  2,029,721     $533,316,061
# 1           1           2008  6.0/10     56,730       $7,948,159
# 2           2           2008  7.9/10    842,429     $318,298,180
# 3           3           2008  6.8/10    388,957     $134,518,390
# 4           4           2009  6.6/10    431,892     $179,737,340
#
#                 Movie_Title
# 0           The Dark Knight
# 1        Punisher: War Zone
# 2                  Iron Man
# 3       The Incredible Hulk
# 4  X-Men Origins: Wolverine

# %%
del movie_rating_sales_df['Unnamed: 0']

# %%
movie_rating_sales_df.head()
# Out:
#    Date_Released  Rating IMDB_Votes Box_Office_Sales               Movie_Title
# 0           2008  9.0/10  2,029,721     $533,316,061           The Dark Knight
# 1           2008  6.0/10     56,730       $7,948,159        Punisher: War Zone
# 2           2008  7.9/10    842,429     $318,298,180                  Iron Man
# 3           2008  6.8/10    388,957     $134,518,390       The Incredible Hulk
# 4           2009  6.6/10    431,892     $179,737,340  X-Men Origins: Wolverine

# %%
merge1 = pd.merge(movie_superhero_df, movie_rating_sales_df, on = 'Movie_Title', how= 'outer')
merge1.head()
# Out:
#    Date_Released_x Publisher Superhero_Name               Movie_Title  \
# 0             2008        DC         Batman           The Dark Knight
# 1             2008        DC       Punisher        Punisher: War Zone
# 2             2008    Marvel       Iron Man                  Iron Man
# 3             2008    Marvel           Hulk       The Incredible Hulk
# 4             2009    Marvel      Wolverine  X-Men Origins: Wolverine
#
#    Date_Released_y  Rating IMDB_Votes Box_Office_Sales
# 0             2008  9.0/10  2,029,721     $533,316,061
# 1             2008  6.0/10     56,730       $7,948,159
# 2             2008  7.9/10    842,429     $318,298,180
# 3             2008  6.8/10    388,957     $134,518,390
# 4             2009  6.6/10    431,892     $179,737,340

# %%
attribute_df.head()
# Out:
#    Unnamed: 0             name Gender Eye color       Race Hair color  Height  \
# 0          29          Ant-Man   Male      blue      Human      Blond     211
# 1          37          Aquaman   Male      blue  Atlantean      Blond     185
# 2          68           Batman   Male      blue      Human      black     188
# 3         105    Black Panther   Male     brown      Human      Black     183
# 4         148  Captain America   Male      blue      Human      blond     188
#
#        Publisher Skin color Alignment  Weight
# 0  Marvel Comics          -      good     122
# 1      DC Comics          -      good     146
# 2      DC Comics          -      good      95
# 3  Marvel Comics          -      good      90
# 4  Marvel Comics          -      good     108

# %%
attribute_df.rename(columns={'name':'Superhero_Name'},inplace=True)
attribute_df.head()
# Out:
#    Unnamed: 0   Superhero_Name Gender Eye color       Race Hair color  Height  \
# 0          29          Ant-Man   Male      blue      Human      Blond     211
# 1          37          Aquaman   Male      blue  Atlantean      Blond     185
# 2          68           Batman   Male      blue      Human      black     188
# 3         105    Black Panther   Male     brown      Human      Black     183
# 4         148  Captain America   Male      blue      Human      blond     188
#
#        Publisher Skin color Alignment  Weight
# 0  Marvel Comics          -      good     122
# 1      DC Comics          -      good     146
# 2      DC Comics          -      good      95
# 3  Marvel Comics          -      good      90
# 4  Marvel Comics          -      good     108

# %%
merge = pd.merge(merge1, attribute_df, on = 'Superhero_Name', how= 'left')
merge
# Out:
#     Date_Released_x Publisher_x   Superhero_Name  \
# 0              2008          DC           Batman
# 1              2008          DC         Punisher
# 2              2008      Marvel         Iron Man
# 3              2008      Marvel             Hulk
# 4              2009      Marvel        Wolverine
# 5              2010      Marvel         Iron Man
# 6              2011      Marvel      Ghost Rider
# 7              2011          DC    Green Lantern
# 8              2011      Marvel             Thor
# 9              2011      Marvel  Captain America
# 10             2012          DC           Batman
# 11             2012      Marvel       Spider-Man
# 12             2013      Marvel         Iron Man
# 13             2013      Marvel             Thor
# 14             2013      Marvel        Wolverine
# 15             2014          DC         Superman
# 16             2014      Marvel       Spider-Man
# 17             2014      Marvel  Captain America
# ...

# %%
del merge['Date_Released_y']
del merge['Publisher_y']
del merge['Unnamed: 0']
merge.rename(columns={'Date_Released_x':'Date_Released','Publisher_x':'Publisher'}, inplace= True)
merge.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title  Rating  \
# 0           2008        DC         Batman           The Dark Knight  9.0/10
# 1           2008        DC       Punisher        Punisher: War Zone  6.0/10
# 2           2008    Marvel       Iron Man                  Iron Man  7.9/10
# 3           2008    Marvel           Hulk       The Incredible Hulk  6.8/10
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine  6.6/10
#
#   IMDB_Votes Box_Office_Sales Gender Eye color               Race Hair color  \
# 0  2,029,721     $533,316,061   Male      blue              Human      black
# 1     56,730       $7,948,159   Male      blue              Human      Black
# 2    842,429     $318,298,180   Male      blue              Human      Black
# 3    388,957     $134,518,390   Male     green  Human / Radiation      Green
# 4    431,892     $179,737,340   Male      blue             Mutant      Black
#
#    Height Skin color Alignment  Weight
# ...

# %%
Inflation_df = pd.read_csv('./Datasets/Production_data/Inflation_adjustments.csv') 
Inflation_df.head()
# Out:
#    Year  Rate
# 0  2008  17.4
# 1  2009  17.8
# 2  2010  15.9
# 3  2011  12.4
# 4  2012  10.1

# %%
merge['Box_Office_Sales'] = merge['Box_Office_Sales'].str.replace('$','')
merge['Box_Office_Sales'] = merge['Box_Office_Sales'].str.replace(',','')
merge['Box_Office_Sales'] = merge['Box_Office_Sales'].str.replace(' ','')
merge['Box_Office_Sales'] = merge['Box_Office_Sales'].astype(int)
merge.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title  Rating  \
# 0           2008        DC         Batman           The Dark Knight  9.0/10
# 1           2008        DC       Punisher        Punisher: War Zone  6.0/10
# 2           2008    Marvel       Iron Man                  Iron Man  7.9/10
# 3           2008    Marvel           Hulk       The Incredible Hulk  6.8/10
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine  6.6/10
#
#   IMDB_Votes  Box_Office_Sales Gender Eye color               Race Hair color  \
# 0  2,029,721         533316061   Male      blue              Human      black
# 1     56,730           7948159   Male      blue              Human      Black
# 2    842,429         318298180   Male      blue              Human      Black
# 3    388,957         134518390   Male     green  Human / Radiation      Green
# 4    431,892         179737340   Male      blue             Mutant      Black
#
#    Height Skin color Alignment  Weight
# ...

# %%
merge['Rating'] = merge['Rating'].str.replace('/10','')
merge['Rating'] = merge['Rating'].str.replace(' ','')
merge['Rating'] = merge['Rating'].astype(float)
merge['Rating'] = merge['Rating'] * 10
merge.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title  Rating  \
# 0           2008        DC         Batman           The Dark Knight    90.0
# 1           2008        DC       Punisher        Punisher: War Zone    60.0
# 2           2008    Marvel       Iron Man                  Iron Man    79.0
# 3           2008    Marvel           Hulk       The Incredible Hulk    68.0
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine    66.0
#
#   IMDB_Votes  Box_Office_Sales Gender Eye color               Race Hair color  \
# 0  2,029,721         533316061   Male      blue              Human      black
# 1     56,730           7948159   Male      blue              Human      Black
# 2    842,429         318298180   Male      blue              Human      Black
# 3    388,957         134518390   Male     green  Human / Radiation      Green
# 4    431,892         179737340   Male      blue             Mutant      Black
#
#    Height Skin color Alignment  Weight
# ...

# %%
rate = []
for index , value in enumerate(merge['Date_Released']):
    number = Inflation_df[Inflation_df['Year'] == value]['Rate'].values[0]
    #print(number)
    rate.append(number)
merge['rate'] = rate
merge.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title  Rating  \
# 0           2008        DC         Batman           The Dark Knight    90.0
# 1           2008        DC       Punisher        Punisher: War Zone    60.0
# 2           2008    Marvel       Iron Man                  Iron Man    79.0
# 3           2008    Marvel           Hulk       The Incredible Hulk    68.0
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine    66.0
#
#   IMDB_Votes  Box_Office_Sales Gender Eye color               Race Hair color  \
# 0  2,029,721         533316061   Male      blue              Human      black
# 1     56,730           7948159   Male      blue              Human      Black
# 2    842,429         318298180   Male      blue              Human      Black
# 3    388,957         134518390   Male     green  Human / Radiation      Green
# 4    431,892         179737340   Male      blue             Mutant      Black
#
# ...

# %%
merge['Inflation_Sales'] = ((merge['rate'] /100) + 1)* merge['Box_Office_Sales']
merge.head()
# Out:
#    Date_Released Publisher Superhero_Name               Movie_Title  Rating  \
# 0           2008        DC         Batman           The Dark Knight    90.0
# 1           2008        DC       Punisher        Punisher: War Zone    60.0
# 2           2008    Marvel       Iron Man                  Iron Man    79.0
# 3           2008    Marvel           Hulk       The Incredible Hulk    68.0
# 4           2009    Marvel      Wolverine  X-Men Origins: Wolverine    66.0
#
#   IMDB_Votes  Box_Office_Sales Gender Eye color               Race Hair color  \
# 0  2,029,721         533316061   Male      blue              Human      black
# 1     56,730           7948159   Male      blue              Human      Black
# 2    842,429         318298180   Male      blue              Human      Black
# 3    388,957         134518390   Male     green  Human / Radiation      Green
# 4    431,892         179737340   Male      blue             Mutant      Black
#
# ...

# %%
# save file
merge.to_csv('./Datasets/Production_data/Merged_Superhero.csv')
