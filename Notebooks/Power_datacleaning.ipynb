# %%
import csv as csv
import pandas as pd
import numpy as np

# %%
powers_df=pd.read_csv("super_hero_powers_test.csv")

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1   Abe Sapien     True                 True               False
# 2     Abin Sur    False                False                True
# 3       A-Bomb    False                 True               False
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False             True        True    False
# 2                  False            False       False    False
# 3                  False            False        True    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# 0              False   False     ...             False            False
# ...

# %%
powers_df['Agility'] = powers_df['Agility'].map({True: 0.5, False: 0})
powers_df["Accelerated Healing"]=powers_df["Accelerated Healing"].map({True:5,False:0})
powers_df["Adaptation"]=powers_df["Adaptation"].map({True:0.5,False:0})
powers_df["Animal Attributes"]=powers_df["Animal Attributes"].map({True:0.5,False:0})
powers_df["Animal Control"]=powers_df["Animal Control"].map({True:2.5,False:0})
powers_df["Animal Oriented Powers"]=powers_df["Animal Oriented Powers"].map({True:0.5,False:0})
powers_df["Animation"]=powers_df["Animation"].map({True:0.5,False:0})
powers_df["Anti-Gravity"]=powers_df["Anti-Gravity"].map({True:2.5,False:0})
powers_df["Astral Projection"]=powers_df["Astral Projection"].map({True:1.5,False:0})
powers_df["Astral Travel"]=powers_df["Astral Travel"].map({True:1.5,False:0})
powers_df["Audio Control"]=powers_df["Audio Control"].map({True:0.5,False:0})
powers_df["Banish"]=powers_df["Banish"].map({True:1.5,False:0})
powers_df["Biokinesis"]=powers_df["Biokinesis"].map({True:0.5,False:0})
powers_df["Camouflage"]=powers_df["Camouflage"].map({True:0.5,False:0})
powers_df["Changing Armor"]=powers_df["Changing Armor"].map({True:0.5,False:0})
powers_df["Clairvoyance"]=powers_df["Clairvoyance"].map({True:1,False:0})
powers_df["Cloaking"]=powers_df["Cloaking"].map({True:2,False:0})
powers_df["Cold Resistance"]=powers_df["Cold Resistance"].map({True:2,False:0})
powers_df["Cryokinesis"]=powers_df["Cryokinesis"].map({True:0.5,False:0})
powers_df["Danger Sense"]=powers_df["Danger Sense"].map({True:2.5,False:0})
powers_df["Darkforce Manipulation"]=powers_df["Darkforce Manipulation"].map({True:20,False:0})
powers_df["Death Touch"]=powers_df["Death Touch"].map({True:10,False:0})
powers_df["Density Control"]=powers_df["Density Control"].map({True:1,False:0})
powers_df["Dexterity"]=powers_df["Dexterity"].map({True:0.5,False:0})
powers_df["Dimensional Awareness"]=powers_df["Dimensional Awareness"].map({True:0.5,False:0})
powers_df["Dimensional Travel"]=powers_df["Dimensional Travel"].map({True:5,False:0})
powers_df["Duplication"]=powers_df["Duplication"].map({True:0.5,False:0})
powers_df["Durability"]=powers_df["Durability"].map({True:0.5,False:0})
powers_df["Echolocation"]=powers_df["Echolocation"].map({True:0.5,False:0})
powers_df["Elasticity"]=powers_df["Elasticity"].map({True:0.5,False:0})
powers_df["Electrical Transport"]=powers_df["Electrical Transport"].map({True:0.5,False:0})
powers_df["Electrokinesis"]=powers_df["Electrokinesis"].map({True:0.5,False:0})
powers_df["Element Control"]=powers_df["Element Control"].map({True:0.5,False:0})
powers_df["Elemental Transmogrification"]=powers_df["Elemental Transmogrification"].map({True:10,False:0})
powers_df["Empathy"]=powers_df["Empathy"].map({True:0.5,False:0})
powers_df["Energy Absorption"]=powers_df["Energy Absorption"].map({True:2.5,False:0})
powers_df["Energy Armor"]=powers_df["Energy Armor"].map({True:0.5,False:0})
powers_df["Energy Beams"]=powers_df["Energy Beams"].map({True:0.5,False:0})
powers_df["Energy Blasts"]=powers_df["Energy Blasts"].map({True:0.5,False:0})
powers_df["Energy Constructs"]=powers_df["Energy Constructs"].map({True:2.5,False:0})
powers_df["Energy Manipulation"]=powers_df["Energy Manipulation"].map({True:0.5,False:0})
powers_df["Energy Resistance"]=powers_df["Energy Resistance"].map({True:0.5,False:0})
powers_df["Enhanced Hearing"]=powers_df["Enhanced Hearing"].map({True:0.5,False:0})
powers_df["Enhanced Memory"]=powers_df["Enhanced Memory"].map({True:5,False:0})
powers_df["Enhanced Senses"]=powers_df["Enhanced Senses"].map({True:0.5,False:0})
powers_df["Enhanced Sight"]=powers_df["Enhanced Sight"].map({True:0.5,False:0})
powers_df["Enhanced Smell"]=powers_df["Enhanced Smell"].map({True:0.5,False:0})
powers_df["Enhanced Touch"]=powers_df["Enhanced Touch"].map({True:0.5,False:0})
powers_df["Fire Control"]=powers_df["Fire Control"].map({True:2.5,False:0})
powers_df["Fire Resistance"]=powers_df["Fire Resistance"].map({True:0.5,False:0})
powers_df["Flight"]=powers_df["Flight"].map({True:0.5,False:0})
powers_df["Force Fields"]=powers_df["Force Fields"].map({True:1.5,False:0})
powers_df["Gliding"]=powers_df["Gliding"].map({True:0.5,False:0})
powers_df["Gravity Control"]=powers_df["Gravity Control"].map({True:1.5,False:0})
powers_df["Grim Reaping"]=powers_df["Grim Reaping"].map({True:5,False:0})
powers_df["Hair Manipulation"]=powers_df["Hair Manipulation"].map({True:1.5,False:0})
powers_df["Heat Generation"]=powers_df["Heat Generation"].map({True:0.5,False:0})
powers_df["Heat Resistance"]=powers_df["Heat Resistance"].map({True:2,False:0})
powers_df["Hyperkinesis"]=powers_df["Hyperkinesis"].map({True:1,False:0})
powers_df["Hypnokinesis"]=powers_df["Hypnokinesis"].map({True:0.5,False:0})
powers_df["Illumination"]=powers_df["Illumination"].map({True:0.5,False:0})
powers_df["Illusions"]=powers_df["Illusions"].map({True:0.5,False:0})
powers_df["Immortality"]=powers_df["Immortality"].map({True:25,False:0})
powers_df["Insanity"]=powers_df["Insanity"].map({True:0.5,False:0})
powers_df["Intangibility"]=powers_df["Intangibility"].map({True:0.5,False:0})
powers_df["Intelligence"]=powers_df["Intelligence"].map({True:0.5,False:0})
powers_df["Intuitive aptitude"]=powers_df["Intuitive aptitude"].map({True:1,False:0})
powers_df["Invisibility"]=powers_df["Invisibility"].map({True:7.5,False:0})
powers_df["Invulnerability"]=powers_df["Invulnerability"].map({True:5,False:0})
powers_df["Jump"]=powers_df["Jump"].map({True:0.5,False:0})
powers_df["Lantern Power Ring"]=powers_df["Lantern Power Ring"].map({True:25,False:0})
powers_df["Levitation"]=powers_df["Levitation"].map({True:0.5,False:0})
powers_df["Light Control"]=powers_df["Light Control"].map({True:5,False:0})
powers_df["Longevity"]=powers_df["Longevity"].map({True:1,False:0})
powers_df["Magic"]=powers_df["Magic"].map({True:7.5,False:0})
powers_df["Magic Resistance"]=powers_df["Magic Resistance"].map({True:2.5,False:0})
powers_df["Magnetism"]=powers_df["Magnetism"].map({True:7.5,False:0})
powers_df["Marksmanship"]=powers_df["Marksmanship"].map({True:0.5,False:0})
powers_df["Matter Absorption"]=powers_df["Matter Absorption"].map({True:5,False:0})
powers_df["Melting"]=powers_df["Melting"].map({True:5,False:0})
powers_df["Mind Blast"]=powers_df["Mind Blast"].map({True:1.5,False:0})
powers_df["Mind Control"]=powers_df["Mind Control"].map({True:7.5,False:0})
powers_df["Mind Control Resistance"]=powers_df["Mind Control Resistance"].map({True:5,False:0})
powers_df["Molecular Combustion"]=powers_df["Molecular Combustion"].map({True:1.5,False:0})
powers_df["Molecular Dissipation"]=powers_df["Molecular Dissipation"].map({True:1.5,False:0})
powers_df["Molecular Manipulation"]=powers_df["Molecular Manipulation"].map({True:7.5,False:0})
powers_df["Natural Armor"]=powers_df["Natural Armor"].map({True:0.5,False:0})
powers_df["Natural Weapons"]=powers_df["Natural Weapons"].map({True:0.5,False:0})
powers_df["Nova Force"]=powers_df["Nova Force"].map({True:25,False:0})
powers_df["Odin Force"]=powers_df["Odin Force"].map({True:40,False:0})
powers_df["Omnilingualism"]=powers_df["Omnilingualism"].map({True:0.5,False:0})
powers_df["Omnipotent"]=powers_df["Omnipotent"].map({True:50,False:0})
powers_df["Omnipresent"]=powers_df["Omnipresent"].map({True:15,False:0})
powers_df["Omniscient"]=powers_df["Omniscient"].map({True:25,False:0})
powers_df["Omnitrix"]=powers_df["Omnitrix"].map({True:7.5,False:0})
powers_df["Peak Human Condition"]=powers_df["Peak Human Condition"].map({True:3,False:0})
powers_df["Phasing"]=powers_df["Phasing"].map({True:0.5,False:0})
powers_df["Phoenix Force"]=powers_df["Phoenix Force"].map({True:40,False:0})
powers_df["Photographic Reflexes"]=powers_df["Photographic Reflexes"].map({True:0.5,False:0})
powers_df["Plant Control"]=powers_df["Plant Control"].map({True:0.5,False:0})
powers_df["Portal Creation"]=powers_df["Portal Creation"].map({True:0.5,False:0})
powers_df["Possession"]=powers_df["Possession"].map({True:1,False:0})
powers_df["Power Absorption"]=powers_df["Power Absorption"].map({True:5,False:0})
powers_df["Power Augmentation"]=powers_df["Power Augmentation"].map({True:0.5,False:0})
powers_df["Power Cosmic"]=powers_df["Power Cosmic"].map({True:40,False:0})
powers_df["Power Nullifier"]=powers_df["Power Nullifier"].map({True:10,False:0})
powers_df["Power Sense"]=powers_df["Power Sense"].map({True:2.5,False:0})
powers_df["Power Suit"]=powers_df["Power Suit"].map({True:5,False:0})
powers_df["Precognition"]=powers_df["Precognition"].map({True:1,False:0})
powers_df["Probability Manipulation"]=powers_df["Probability Manipulation"].map({True:5,False:0})
powers_df["Projection"]=powers_df["Projection"].map({True:0.5,False:0})
powers_df["Psionic Powers"]=powers_df["Psionic Powers"].map({True:0.5,False:0})
powers_df["Qwardian Power Ring"]=powers_df["Qwardian Power Ring"].map({True:17.5,False:0})
powers_df["Radar Sense"]=powers_df["Radar Sense"].map({True:2.5,False:0})
powers_df["Radiation Absorption"]=powers_df["Radiation Absorption"].map({True:0.5,False:0})
powers_df["Radiation Control"]=powers_df["Radiation Control"].map({True:0.5,False:0})
powers_df["Radiation Immunity"]=powers_df["Radiation Immunity"].map({True:2,False:0})
powers_df["Reality Warping"]=powers_df["Reality Warping"].map({True:12.5,False:0})
powers_df["Reflexes"]=powers_df["Reflexes"].map({True:0.5,False:0})
powers_df["Regeneration"]=powers_df["Regeneration"].map({True:12.5,False:0})
powers_df["Resurrection"]=powers_df["Resurrection"].map({True:15,False:0})
powers_df["Seismic Power"]=powers_df["Seismic Power"].map({True:1.5,False:0})
powers_df["Self-Sustenance"]=powers_df["Self-Sustenance"].map({True:0.5,False:0})
powers_df["Shapeshifting"]=powers_df["Shapeshifting"].map({True:5,False:0})
powers_df["Size Changing"]=powers_df["Size Changing"].map({True:1,False:0})
powers_df["Sonar"]=powers_df["Sonar"].map({True:0.5,False:0})
powers_df["Sonic Scream"]=powers_df["Sonic Scream"].map({True:0.5,False:0})
powers_df["Spatial Awareness"]=powers_df["Spatial Awareness"].map({True:1,False:0})
powers_df["Speed Force"]=powers_df["Speed Force"].map({True:22.5,False:0})
powers_df["Stamina"]=powers_df["Stamina"].map({True:0.5,False:0})
powers_df["Stealth"]=powers_df["Stealth"].map({True:1,False:0})
powers_df["Sub-Mariner"]=powers_df["Sub-Mariner"].map({True:5,False:0})
powers_df["Substance Secretion"]=powers_df["Substance Secretion"].map({True:2,False:0})
powers_df["Summoning"]=powers_df["Summoning"].map({True:0.5,False:0})
powers_df["Super Breath"]=powers_df["Super Breath"].map({True:0.5,False:0})
powers_df["Super Speed"]=powers_df["Super Speed"].map({True:0.5,False:0})
powers_df["Super Strength"]=powers_df["Super Strength"].map({True:0.5,False:0})
powers_df["Symbiote Costume"]=powers_df["Symbiote Costume"].map({True:0.5,False:0})
powers_df["Technopath/Cyberpath"]=powers_df["Technopath/Cyberpath"].map({True:1,False:0})
powers_df["Telekinesis"]=powers_df["Telekinesis"].map({True:1,False:0})
powers_df["Telepathy"]=powers_df["Telepathy"].map({True:5,False:0})
powers_df["Telepathy Resistance"]=powers_df["Telepathy Resistance"].map({True:0.5,False:0})
powers_df["Teleportation"]=powers_df["Teleportation"].map({True:12.5,False:0})
powers_df["Terrakinesis"]=powers_df["Terrakinesis"].map({True:0.5,False:0})
powers_df["The Force"]=powers_df["The Force"].map({True:17.5,False:0})
powers_df["Thirstokinesis"]=powers_df["Thirstokinesis"].map({True:0.5,False:0})
powers_df["Time Manipulation"]=powers_df["Time Manipulation"].map({True:15,False:0})
powers_df["Time Travel"]=powers_df["Time Travel"].map({True:20,False:0})
powers_df["Toxin and Disease Control"]=powers_df["Toxin and Disease Control"].map({True:0.5,False:0})
powers_df["Toxin and Disease Resistance"]=powers_df["Toxin and Disease Resistance"].map({True:2.5,False:0})
powers_df["Underwater breathing"]=powers_df["Underwater breathing"].map({True:1,False:0})
powers_df["Vision - Cryo"]=powers_df["Vision - Cryo"].map({True:0.5,False:0})
powers_df["Vision - Heat"]=powers_df["Vision - Heat"].map({True:2.5,False:0})
powers_df["Vision - Infrared"]=powers_df["Vision - Infrared"].map({True:0.5,False:0})
powers_df["Vision - Microscopic"]=powers_df["Vision - Microscopic"].map({True:0.5,False:0})
powers_df["Vision - Night"]=powers_df["Vision - Night"].map({True:0.5,False:0})
powers_df["Vision - Telescopic"]=powers_df["Vision - Telescopic"].map({True:0.5,False:0})
powers_df["Vision - Thermal"]=powers_df["Vision - Thermal"].map({True:0.5,False:0})
powers_df["Vision - X-Ray"]=powers_df["Vision - X-Ray"].map({True:0.5,False:0})
powers_df["Vitakinesis"]=powers_df["Vitakinesis"].map({True:0.5,False:0})
powers_df["Wallcrawling"]=powers_df["Wallcrawling"].map({True:0.5,False:0})
powers_df["Water Control"]=powers_df["Water Control"].map({True:0.5,False:0})
powers_df["Weapon-based Powers"]=powers_df["Weapon-based Powers"].map({True:0.5,False:0})
powers_df["Weapons Master"]=powers_df["Weapons Master"].map({True:2.5,False:0})
powers_df["Weather Control"]=powers_df["Weather Control"].map({True:5,False:0})
powers_df["Web Creation"]=powers_df["Web Creation"].map({True:2.5,False:0})
powers_df["Wind Control"]=powers_df["Wind Control"].map({True:0.5,False:0})

# %%
powers_df.tail()
# Out:
#           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 662  Yellowjacket II      0.0                    0                   0
# 663             Ymir      0.0                    0                   0
# 664             Yoda      0.5                    0                   0
# 665          Zatanna      0.0                    0                   0
# 666             Zoom      0.0                    0                   0
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 662                    0.0                0         0.0        0
# 663                    0.0                2         0.5        0
# 664                    0.0                0         0.0        1
# 665                    0.0                0         0.0        0
# 666                    0.0                0         0.0        0
#
#      Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# ...

# %%
powers_df["Weight"]=powers_df.sum(axis=1)

# %%
powers_df.tail()
# Out:
#           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 662  Yellowjacket II      0.0                    0                   0
# 663             Ymir      0.0                    0                   0
# 664             Yoda      0.5                    0                   0
# 665          Zatanna      0.0                    0                   0
# 666             Zoom      0.0                    0                   0
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 662                    0.0                0         0.0        0
# 663                    0.0                2         0.5        0
# 664                    0.0                0         0.0        1
# 665                    0.0                0         0.0        0
# 666                    0.0                0         0.0        0
#
#      Energy Absorption  Flight   ...    Reality Warping  Odin Force  \
# 662                0.0     0.5   ...                0.0           0
# ...

# %%
powers_df.to_csv("new_powers.csv")
